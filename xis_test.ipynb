# %%
import sys
exec(open('load.py').read())
exec(open('example1.py').read())
exec(open('example2.py').read())
# Out:
# Python: 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# numpy: 1.26.4
# scipy: 1.13.1
# matplotlib: 3.10.0
# pandas: 2.2.2
# sklearn: 1.6.0
# Python: 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# scipy: 1.13.1
# numpy: 1.26.4
# matplotlib: 3.10.0
# pandas: 2.2.2
# sklearn: 1.6.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# %%
import csv

# %% [markdown]
# # In this section we apply clustering methods to a dataset generated on purpose (MeanShift method)

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs
from mpl_toolkits.mplot3d import Axes3D

# %%
exec(open('''load.py''').read())
exec(open('''example1.py''').read())
exec(open('''example2.py''').read())
# Out:
# Python: 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# numpy: 1.26.4
# scipy: 1.13.1
# matplotlib: 3.10.0
# pandas: 2.2.2
# sklearn: 1.6.0
# Python: 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# scipy: 1.13.1
# numpy: 1.26.4
# matplotlib: 3.10.0
# pandas: 2.2.2
# sklearn: 1.6.0

# %%
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=4812, centers=centers, cluster_std=0.6)

# %%
print(X.shape)
# Out:
# (4812, 2)

# %%
plt.scatter(X[:, 0], X[:, 1]) #plotting the y's X[:1] vs x's X[:0]

# %%
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500) #automatic detcted bw

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
print("numero stimato di cluster :", n_clusters_ )
# Out:
# numero stimato di cluster : 3

# %%
plt.figure(1)
plt.clf()

colors = ["#dede00", "#377eb8", "#f781bf"]
markers = ["o", "s", "v"]
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    print(my_members)
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], marker=markers[k], color=col)
    plt.plot(cluster_center[0], cluster_center[1], marker="o", markerfacecolor=col, markeredgecolor="k", markersize=14)
    plt.title("Estimated number of clusters: %d" % n_clusters_)
# Out:
# [False False False ... False False  True]
# [False  True  True ...  True  True False]
# [ True False False ... False False False]

# %%
print(X[False,0])
# Out:
# []

# %% [markdown]
# #Real data are handled here. Parameters representing properties

# %%
with open('fort.114', 'r') as file:
    xis = read_csv(file)
    print(xis)
# Out:
#                         ifi    iss RES x1  x2  x3 xm xp
# 0         1      1 PHE    0.10552    0.35548    0.86...
# 1         1      1 PRO    0.15070    0.40681    0.52...
# 2         1      1 PHE    0.13666    0.57766    0.94...
# 3         1      2 ALA    0.44376    0.61446    0.72...
# 4         1      1 LEU    0.15412    0.54401    0.56...
# ...                                                 ...
# 4807     42    102 HIS    0.28669    0.74044    0.89...
# 4808     42    103 HIS    0.31639    0.73114    0.88...
# 4809     42    104 HIS    0.37992    0.74335    0.78...
# 4810     42    105 HIS    0.24386    0.72347    0.96...
# 4811     42    106 HIS    0.18773    0.72165    0.94...
#
# [4812 rows x 1 columns]

# %%
scatter_matrix(xis)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-6e70e3415fa3> in <cell line: 1>()
# ----> 1 scatter_matrix(xis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     218     """
#     219     plot_backend = _get_plot_backend("matplotlib")
# --> 220     return plot_backend.scatter_matrix(
#     221         frame=frame,
#     222         alpha=alpha,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      48     n = df.columns.size
#      49     naxes = n * n
# ---> 50     fig, axes = create_subplots(naxes=naxes, figsize=figsize, ax=ax, squeeze=False)
#      51
# ...

# %%
file = open('classification_data', 'r')
data = file.read()

# %%
with open('classification_data', 'r') as ff:
  newxis = read_csv(ff)
  print(newxis.describe())
  print(newxis.shape)
# Out:
#                 x1           x2           x3
# count  4812.000000  4812.000000  4812.000000
# mean      0.210651     0.636306     0.930508
# std       0.098215     0.196722     0.830888
# min       0.000460     0.078410     0.476240
# 25%       0.157780     0.552010     0.654547
# 50%       0.186730     0.630460     0.814555
# 75%       0.255373     0.689355     0.982940
# max       1.087680     1.596160    26.316100
# (4812, 4)

# %%
scatter_matrix(newxis)
# Out:
# array([[<Axes: xlabel='x1', ylabel='x1'>,
#         <Axes: xlabel='x2', ylabel='x1'>,
#         <Axes: xlabel='x3', ylabel='x1'>],
#        [<Axes: xlabel='x1', ylabel='x2'>,
#         <Axes: xlabel='x2', ylabel='x2'>,
#         <Axes: xlabel='x3', ylabel='x2'>],
#        [<Axes: xlabel='x1', ylabel='x3'>,
#         <Axes: xlabel='x2', ylabel='x3'>,
#         <Axes: xlabel='x3', ylabel='x3'>]], dtype=object)

# %%
with open('fort.13', 'r') as ff:
  newxis = read_csv(ff)
  print(newxis.shape)
  print(newxis.describe())
# Out:
# (4811, 4)
#                10           35            86
# count  4811.000000  4811.000000  4811.000000
# mean     20.572022    63.146539    92.561422
# std       9.809175    19.670507    83.097231
# min       0.000000     7.000000    47.000000
# 25%      15.000000    55.000000    65.000000
# 50%      18.000000    63.000000    81.000000
# 75%      25.000000    68.000000    98.000000
# max     108.000000   159.000000  2631.000000

# %%
scatter_matrix(newxis)
# Out:
# array([[<Axes: xlabel='          10 ', ylabel='          10 '>,
#         <Axes: xlabel='          35 ', ylabel='          10 '>,
#         <Axes: xlabel='          86', ylabel='          10 '>],
#        [<Axes: xlabel='          10 ', ylabel='          35 '>,
#         <Axes: xlabel='          35 ', ylabel='          35 '>,
#         <Axes: xlabel='          86', ylabel='          35 '>],
#        [<Axes: xlabel='          10 ', ylabel='          86'>,
#         <Axes: xlabel='          35 ', ylabel='          86'>,
#         <Axes: xlabel='          86', ylabel='          86'>]],
#       dtype=object)

# %% [markdown]
# #Here we an example of classification by a simple KNN approach, K=1.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# %%
x = [4, 5, 10, 4, 3, 11, 14 , 8, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]
z = [30,40,21,55,22,9,70,58,1001,7]
classes = [0, 1, 2, 0, 2, 1, 1, 0, 1, 1]

data = list(zip(x, y, z))

print(data)

knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(data, classes)

nx = 60
ny = 21
nz = 33

newp =  [(nx,ny,nz)]
prediction = knn.predict(newp)
# Out:
# [(4, 21, 30), (5, 19, 40), (10, 24, 21), (4, 17, 55), (3, 16, 22), (11, 25, 9), (14, 24, 70), (8, 22, 58), (10, 21, 1001), (12, 21, 7)]

# %%
plt.scatter(x, y, z, c = classes)

# %%
plt.scatter(x +[nx], y + [ny], z + [nz], c = classes + [prediction[0]])

# %% [markdown]
# # We can treat a real case. The structure of data can be adopted from the example above, where the three set of values are xi1,xi2,xi3, and the classes are the 21 average values for each amino acid. Need for a preliminar average calculation. The data needed are in the file "classificatio_data" and "fort.12" which contains the classes sequence, for each of the (xi1,xi2,xi3) triple

# %%
print(newxis)
# Out:
#       RES       x1       x2       x3
# 0     PHE  0.10552  0.35548  0.86941
# 1     PRO  0.15070  0.40681  0.52693
# 2     PHE  0.13666  0.57766  0.94010
# 3     ALA  0.44376  0.61446  0.72184
# 4     LEU  0.15412  0.54401  0.56323
# ...   ...      ...      ...      ...
# 4807  HIS  0.28669  0.74044  0.89483
# 4808  HIS  0.31639  0.73114  0.88728
# 4809  HIS  0.37992  0.74335  0.78054
# 4810  HIS  0.24386  0.72347  0.96418
# 4811  HIS  0.18773  0.72165  0.94353
#
# [4812 rows x 4 columns]

# %%
xxxx = pandas.DataFrame(newxis)
print(xxxx)
lst = ['x1']
# Out:
#       RES       x1       x2       x3
# 0     PHE  0.10552  0.35548  0.86941
# 1     PRO  0.15070  0.40681  0.52693
# 2     PHE  0.13666  0.57766  0.94010
# 3     ALA  0.44376  0.61446  0.72184
# 4     LEU  0.15412  0.54401  0.56323
# ...   ...      ...      ...      ...
# 4807  HIS  0.28669  0.74044  0.89483
# 4808  HIS  0.31639  0.73114  0.88728
# 4809  HIS  0.37992  0.74335  0.78054
# 4810  HIS  0.24386  0.72347  0.96418
# 4811  HIS  0.18773  0.72165  0.94353
#
# [4812 rows x 4 columns]

# %%
lst = ['x1']
xx1 = xxxx[xxxx.columns.intersection(lst)]
lst = ['x2']
xx2 = xxxx[xxxx.columns.intersection(lst)]
lst = ['x3']
xx3 = xxxx[xxxx.columns.intersection(lst)]

# %%
xx1 = xxxx['x1'].values.tolist()
xx2 = xxxx['x2'].values.tolist()
xx3 = xxxx['x2'].values.tolist()
with open('fort.12', 'r') as fuffa:
     classes = read_csv(fuffa)
     print(classes)
# Out:
#       RES
# 0      51
# 1      51
# 2      51
# 3      52
# 4      49
# ...   ...
# 4807   52
# 4808   52
# 4809   52
# 4810   52
# 4811   52
#
# [4812 rows x 1 columns]

# %%
c = pandas.DataFrame(classes)
print(c)
c1 = c['RES'].values.tolist()
print(c1)
# Out:
#       RES
# 0      51
# 1      51
# 2      51
# 3      52
# 4      49
# ...   ...
# 4807   52
# 4808   52
# 4809   52
# 4810   52
# 4811   52
#
# [4812 rows x 1 columns]
# ...

# %%
data = list(zip(xx1, xx2, xx3))

knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(data, c1)

nx = 0.2
ny = 0.4
nz = 0.8

newp =  [(nx,ny,nz)]
prediction = knn.predict(newp)
print(prediction)
# Out:
# [48]

# %%
plt.scatter(xx1 + [nx], xx2 + [ny], xx3 + [nz], c = c1 + [prediction[0]])

# %% [markdown]
# In the above cells, the data corresponding to the xis values corresponding to the amino acids in the chain of a given set of proteins are analysed. The data are loaded, in the form of csv files, then labelled manually (columns: RES,x1,x2,x3), then processed using a KNN classifier. Ideally a class per each of the 21 amino acids should be expected. Clearly this is not a realistic expectation ...

# %% [markdown]
# Let us apply the procedure to a 3D data case, the xis, using the same dataset for KNN classifier

# %%
Y = numpy.genfromtxt('xisMeanSh',delimiter= " ",dtype=None)
print(Y)
# Out:
# [[0.10552 0.35548 0.86941]
#  [0.1507  0.40681 0.52693]
#  [0.13666 0.57766 0.9401 ]
#  ...
#  [0.37992 0.74335 0.78054]
#  [0.24386 0.72347 0.96418]
#  [0.18773 0.72165 0.94353]]

# %%
plt.scatter([Y[:,1]], Y[:,2])

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter3D(Y[:,0], Y[:,1], Y[:,2])

# %%
bandwidth = estimate_bandwidth(Y, quantile=0.2, n_samples=500)
print("bandwidth : ",bandwidth)
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(Y)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
print("numero stimato di cluster :", n_clusters_ )
print(labels)
# Out:
# bandwidth :  0.28417149917037954
# numero stimato di cluster : 23
# [2 0 0 ... 0 0 0]

# %%
from random import randint
colors = []

for i in range(23):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
    print(colors[i])
# Out:
# #0FDC85
# #0B5B5C
# #577148
# #74E7E9
# #4F67D7
# #890167
# #B3448E
# #9411A6
# #7BC529
# #097459
# #F29262
# #41A08E
# #AA9EF1
# #C78E3F
# #E3E5AC
# #25A806
# #8AFDDB
# #791278
# #CCBA1B
# #83A434
# #90E544
# #970527
# #F31ABE

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
markers = ["o", "s", "v", 1, 2 ,3, 4]
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    ax.scatter3D(Y[my_members,0], Y[my_members,1], Y[my_members,2], color=col, marker="s")
    ax.scatter3D(cluster_center[0], cluster_center[1], cluster_center[2], marker="p", color='red', s=240)
plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
ax.scatter3D(cluster_centers[:, 0], cluster_centers[:, 1],
           cluster_centers[:, 2], marker ='1', color ='red',
           s = 300, linewidth = 5, zorder = 1000)
ax.set_xlabel('xi1')
ax.set_ylabel('Y Label')
ax.set_zlim(0,10)
ax.set_zlabel('Z Label')

print(labels)
# Out:
# [2 0 0 ... 0 0 0]

# %%
import numpy as np
mat=labels
np.savetxt('labels.txt',mat,fmt='%.6f')

# %% [markdown]
# # In this section we consider a different method of classification, specifically the affinity propagation (Science 16 Feb 2007, Vol 315 Issue 5814 pp 972-76)

# %%
exec(open('load.py').read())
# Out:
# Python: 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# numpy: 1.26.4
# scipy: 1.13.1
# matplotlib: 3.8.0
# pandas: 2.2.2
# sklearn: 1.5.2

# %%
exec(open('example2.py').read())

# %%
from sklearn.cluster import AffinityPropagation

# %%
Y = numpy.genfromtxt('xisMeanSh',delimiter= " ",dtype=None)
print(Y)
# Out:
# [[0.10552 0.35548 0.86941]
#  [0.1507  0.40681 0.52693]
#  [0.13666 0.57766 0.9401 ]
#  ...
#  [0.37992 0.74335 0.78054]
#  [0.24386 0.72347 0.96418]
#  [0.18773 0.72165 0.94353]]

# %% [markdown]
# # Show hyperplanes

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hyperplane: 2x + y - 3 = 0

# Create a range of x values
x = np.linspace(-2, 2, 400)

# Calculate the corresponding y values based on the updated hyperplane equation
y = 3 - 2 * x
y1 = 4 - 2 * x

# The normal vector to the hyperplane 2x + y - 3 = 0 is [2, 1]
normal_vector = np.array([2, 1])

# Plot origin for the normal vector
origin = [0, 0]  # Origin point

# Create the 2D plot with the axes going through the origin (0, 0)
plt.figure()

# Plot the line representing the updated hyperplane in 2D space
plt.plot(x, y, label='Hyperplane: 2x + y - 3 = 0')
plt.plot(x, y1, label='Hyperplane: 2x + y - 4 = 0')

# Plot the normal vector with precise control over its length
plt.quiver(*origin, *normal_vector, scale_units='xy', angles='xy', scale=1, color='red', label='Normal Vector [2, 1]')

# Display the value of the normal vector on the plot
plt.text(1.2, 1.2, f'Normal Vector: [2, 1]', color='red')

# Setting labels
plt.xlabel('X axis')
plt.ylabel('Y axis')

# Move the spines to go through the origin
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.gca().spines['left'].set_position('zero')
plt.gca().spines['bottom'].set_position('zero')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

# Set the aspect of the plot to be equal
plt.axis('equal')

# Setting plot limits for better visualization
plt.xlim([-2, 2])
plt.ylim([-2, 5])

# Adding a legend
plt.legend()

# Show the plot
plt.show()
